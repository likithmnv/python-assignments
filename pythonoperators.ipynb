# %% [markdown]
# Arithmetic Operators

# %% [markdown]
# Write a program to perform addition, subtraction, multiplication, division, floor division, modulus, and exponentiation on two numbers.

# %%
num1 = float(input("Enter the first number: "))
num2 = float(input("Enter the second number:"))

print("Addition =", num1 + num2)
print("Subtraction =", num1 - num2)
print("Multiplication =", num1 * num2)

if num2 != 0:
  print("Division =", num1 / num2)
  print("Floor Division =", num1 // num2)
  print("Modulus =", num1 % num2)
else:
    print("Division, Floor Division and Modulus cannot be performed dbecause the second number is 0. ")

print("Exponentation =", num1 ** num2)
# Out:
# Enter the first number: 3
# Enter the second number:7
# Addition = 10.0
# Subtraction = -4.0
# Multiplication = 21.0
# Division = 0.42857142857142855
# Floor Division = 0.0
# Modulus = 3.0
# Exponentation = 2187.0

# %% [markdown]
# Swap two numbers without using a third variable.

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

a = a + b
b = a - b
a = a - b

print("After swapping")
print("First number =", a)
print("Second number =", b)
# Out:
# Enter first number: 34
# Enter second number: 26
# After swapping
# First number = 26
# Second number = 34

# %% [markdown]
# Find whether a number is even or odd using the modulus operator.

# %%
num = int(input("Enter a number: "))

if num % 2 == 0:
  print("The number is Even")
else:
  print("The numberis Odd")
# Out:
# Enter a number: 44
# The number is Even

# %% [markdown]
# Reverse a three-digit number using arithmetic operators.

# %%
num = int(input("Enter a three-digit number: "))

hundreds = num // 100
tens = (num // 10) % 10
ones =num % 10

reverse = ones * 100 + tens * 10 + hundreds

print("Rversed number= ", reverse)
# Out:
# Enter a three-digit number: 643
# Rversed number=  346

# %% [markdown]
# Find the last digit and first digit of a given number.

# %%
num = int(input("Enter a number: "))

last_digit = num % 10

first_digit = num
while first_digit >= 10:
  first_digit = first_digit // 10

print("First digit=", first_digit)
print("Last_digit=", last_digit)
# Out:
# Enter a number: 59
# First digit= 5
# Last_digit= 9

# %% [markdown]
# Assignment Operators

# %% [markdown]
# Demonstrate all assignment operators (=, +=, -=, *=, /=, //=, %= and **=) on a variable.

# %%
x = 10
print("Initial value of x =", x)
x = 20
print("After x = 20        :", x)
x += 5
print("After x += 5        :", x)
x -= 8
print("After x -=8         :", x)
x *= 4
print("After x *=4         :", x)
x /= 6
print("After x /=6         :", x)
x //= 9
print("After x //=9        :", x)
x %= 7
print("After x % = 7       :", x)
x **= 3
print("After x **= 3       :", x)
# Out:
# Initial value of x = 10
# After x = 20        : 20
# After x += 5        : 25
# After x -=8         : 17
# After x *=4         : 68
# After x /=6         : 11.333333333333334
# After x //=9        : 1.0
# After x % = 7       : 1.0
# After x **= 3       : 1.0

# %% [markdown]
# Update a bank account balance using compound assignment operators.

# %%
balance = float(input("Enter initial balance: "))

deposit = float(input("Enter deposit amount: "))
balance += deposit
print("Balance after deposit =", balance)

withdraw = float(input("Enter withdraw amount: "))
balance -= withdraw
print("Balance after withdrwal=", balance)

balance *= 2.09
print("Balance after 6% interest =", balance)

balance *= 2
print("Balance after 2% service charge =", balance)
# Out:
# Enter initial balance: 25000
# Enter deposit amount: 10000
# Balance after deposit = 35000.0
# Enter withdraw amount: 5000
# Balance after withdrwal= 30000.0
# Balance after 6% interest = 62699.99999999999
# Balance after 2% service charge = 125399.99999999999

# %% [markdown]
# Calculate the total marks using += inside a loop.

# %%
total = 0

for i in range(1, 7):
  marks = int(input(f"Enter marks for subject {i}: "))
  total += marks

print("Total marks= ", total)
# Out:
# Enter marks for subject 1: 54
# Enter marks for subject 2: 64
# Enter marks for subject 3: 73
# Enter marks for subject 4: 43
# Enter marks for subject 5: 68
# Enter marks for subject 6: 98
# Total marks=  400

# %% [markdown]
# Comparison Operators

# %% [markdown]
# ompare two numbers and print the larger number.

# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

if num1 > num2:
  print("Larger number=", num1)
elif num2> num1:
  print("Larger number=", num2)
else:
  print("Both numbers are equal.")
# Out:
# Enter first number: 53
# Enter second number: 76
# Larger number= 76.0

# %% [markdown]
# Check whether three numbers are equal.

# %%
num1 = int(input("Enter first numebr: "))
num2 = int(input("Enter second number: "))
num3 = int(input("Enter third number: "))

if num1 == num2 == num3:
  print("All three numbers are equal.")
else:
  print("The numbers are not equal.")
# Out:
# Enter first numebr: 33
# Enter second number: 33
# Enter third number: 33
# All three numbers are equal.

# %% [markdown]
# Find the largest among three numbers using comparison operators.

# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
num3 = float(input("Enter third number:"))

if num1 >= num2 and num1 >= num3:
  largest = num1
elif num2 >= num1 and num2 >= num3:
  largest = num2
else:
  largest = num3

  print("Largest number=", largest)
# Out:
# Enter first number: 43
# Enter second number: 22
# Enter third number:56
# Largest number= 56.0

# %% [markdown]
# Check whether a student is eligible to vote based on age.

# %%
age = int(input("Enter your age: "))

if age >= 18:
  print("Eligible to vote")
else:
  print("Not eligible to vote")
# Out:
# Enter your age: 22
# Eligible to vote

# %% [markdown]
# Logical Operators

# %% [markdown]
# Check if a person is eligible for a loan (age > 21 AND salary > 30000).

# %%
age = int(input("enter your age: "))
salary = float(input("Enter your monthly salary: "))
if age > 21 and salary > 50000:
  print("Eligible for Trading")
else:
  print("Not eligible for Trading")
# Out:
# enter your age: 22
# Enter your monthly salary: 50000
# Not eligible for Trading

# %% [markdown]
# Check if a number lies between 10 and 100 using logical operators.

# %%
num = int(input("Enter a number: "))

if num >= 10 and num <= 100:
  print("The number lies between 10 and 100.")
else:
  print("The number does not lies between 10 and 100")
# Out:
# Enter a number: 44
# The number lies between 10 and 100.

# %% [markdown]
# alidate username and password using logical operators.

# %%
correct_username = "likith"
correct_admin = "likith@2003"

username = input("Enter username: ")
password = input("Enter password: ")

if username == correct_username and password == correct_admin:
  print("Login successful")
else:
  print("Invalid username or password")
# Out:
# Enter username: likith
# Enter password: likith@2003
# Login successful

# %% [markdown]
# Determine whether a year is a leap year using logical conditions.

# %%
year = int(input("Enter a year: "))

if(year % 400 == 0) or (year % 4 == 0 and year % 100 != 0):
  print(year, "is a Leap Year")
else:
  print(year, "is Not a Leap Year")
# Out:
# Enter a year: 2027
# 2027 is Not a Leap Year

# %% [markdown]
# Bitwise Operators

# %% [markdown]
# Find the bitwise AND, OR, XOR of two numbers.

# %%
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))

print("Bitwise AND =", num1 & num2)
print("Bitwise OR =", num1 | num2)
print("Bitwise XOR =", num1 ^ num2)
# Out:
# Enter first number: 31
# Enter second number: 10
# Bitwise AND = 10
# Bitwise OR = 31
# Bitwise XOR = 21

# %% [markdown]
# Perform left shift and right shift operations.

# %%
num = int(input("Enter a number: "))

shift = int(input("Enter number of shift positions: "))

print("Left shift =", num << shift)
print("Right shift =", num >> shift)
# Out:
# Enter a number: 48
# Enter number of shift positions: 18
# Left shift = 12582912
# Right shift = 0

# %% [markdown]
# Check whether a number is even using a bitwise operator.

# %%
num = int(input("Enter a number: "))

if (num & 1) == 0:
  print("The number is Even")
else:
  print("The number is Odd")
# Out:
# Enter a number: 96
# The number is Even

# %% [markdown]
# Swap two numbers using the XOR operator.

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

a = a ^ b
b = a ^ b
a = a ^ b

print("After swapping:")
print("First number =", a)
print("Second number =",b )
# Out:
# Enter first number: 32
# Enter second number: 97
# After swapping:
# First number = 97
# Second number = 32

# %% [markdown]
# Count how many bits are set to 1 in a number using bitwise operations.

# %%
num = int(input("Enter a number: "))

count = 0
n = num

while n > 0:
  count += (n & 1)
  n = n >> 1

print("Number of set bits =", count)
# Out:
# Enter a number: 6
# Number of set bits = 2

# %% [markdown]
# Identity Operators

# %% [markdown]
# Demonstrate the difference between is and ==.

# %%
a = 100
b = 100

print("a == b :", a == b)
print("a is b :", a is b)

list1 = [20, 40, 60]
list2 = [20, 40, 60]

print("\nlist1 == list2 :", list1 == list2)
print("list1 is list2 :", list1 is list2)

list3 = list1

print("\nlist1 == list3 :", list1 == list3)
print("list1 is list3 :", list1 is list3)
# Out:
# a == b : True
# a is b : True
#
# list1 == list2 : True
# list1 is list2 : False
#
# list1 == list3 : True
# list1 is list3 : True

# %% [markdown]
# Check whether two variables refer to the same list object.

# %%
list1 = [30, 60, 90]
list2 = [30, 60, 90]

print("list1 == list2 :", list1 ==list2)
print("list1 is list2 :", list1 is list2)
# Out:
# list1 == list2 : True
# list1 is list2 : False

# %% [markdown]
# Show the behavior of is not with integers and lists.

# %%
a = 20
b = 30

print("Integers:")
print("a =", a)
print("b =", b)
print("a is not b :", a is not b)

list1 = [4,5,6]
list2 = [4,5,6]
list3 = list1

print("\nLists:")
print("list1 =", list1)
print("list2 =", list2)
print("list3 =", list3)

print("list1 is not list2 :", list1 is not list2)
print("list1 is not list3 :", list1 is not list3)
# Out:
# Integers:
# a = 20
# b = 30
# a is not b : True
#
# Lists:
# list1 = [4, 5, 6]
# list2 = [4, 5, 6]
# list3 = [4, 5, 6]
# list1 is not list2 : True
# list1 is not list3 : False

# %% [markdown]
# Membership Operators

# %% [markdown]
# Check whether a character exists in a string.

# %%
text = input("Enter a string: ")
ch = input("Enter a character: ")

if ch in text:
  print("Character exist in the string.")
else:
  print("Character does not exist in the string")
# Out:
# Enter a string: 5
# Enter a character: 7
# Character does not exist in the string

# %% [markdown]
# Check whether a number exists in a list.

# %%
numbers = [20, 40, 30, 70, 21]

num = int(input("Enter a number: "))

if num in numbers:
  print("Number exist in the list.")
else:
  print("Number does not exist in the list.")
# Out:
# Enter a number: 40
# Number exist in the list.

# %% [markdown]
# Count how many vowels in a string belong to a predefined vowel list using in.

# %%
text = input("Enter a string: ")

vowels = ['a', 'e', 'i', 'o', 'u']

count = 0

for ch in text.lower():
  if ch in vowels:
    count += 1

print("Number of vowels =", count)
# Out:
# Enter a string: likith
# Number of vowels = 2

# %% [markdown]
# Mixed Operator Programs

# %% [markdown]
# Build a simple calculator using arithmetic and comparison operators.

# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

operator = input("Enter operator (+, -, *, /, //, %, **): ")

if operator == "+":
  print("Result=", num1 + num2)

elif operator == "-":
  print("Result=", num1 - num2)

elif operator == "*":
  print("Result=", num1 * num2)

elif operator == "/":
  if num2 != 0:
    print("Result =", num1 / num2)
  else:
    print("Division by zero is not allowed.")
elif operator == "//":
  if num2 != 0:
    print("Result=", num1 // num2)
  else:
    print("Floor division by zero is not allowed.")

elif operator == "%":
  if num2 != 0:
    print("Result =", num1 % num2)
  else:
    print("Modulus by zero is not allowed.")
# Out:
# Enter first number: 3
# Enter second number: 5
# Enter operator (+, -, *, /, //, %, **): *
# Result= 15.0

# %% [markdown]
# Create a grading system using comparison and logical operators.

# %%
marks = float(input("Enter your marks (0-100): "))

if marks >= 90 and marks <= 100:
  print("Grade: A")
elif marks >= 80 and marks < 90:
  print("Grade: B")
elif marks >= 70 and marks < 80:
  print("Grade: C")
elif marks >= 60 and marks < 70:
  print("Grade: D")
elif marks >= 0 and marks < 50:
  print("Grade: F")
else:
  print("Invalid marks! please enter marks between 0 and 100.")
# Out:
# Enter your marks (0-100): 22
# Grade: F

# %% [markdown]
# Build a menu-driven calculator that uses arithmetic, comparison, logical, assignment, membership, identity, and bitwise operators wherever applicable.

# %%
while True:
  print("\n1.Arithmatic 2.Comparison 3.Logical 4.Assignment")
  print("5.Membership 6.Identity 7.Bitwise 8. Exit")
  ch = int(input("Enter choice: "))

  if ch == 1:
    a, b = map(int, input("Enter two numbers: ").split())
    print ("+, -, *, /, =", a+b, a-b, a*b, a/b )
  elif ch == 2:
    a, b = map(int, input("Enter two numbers: ").split())
    print("==", a==b, ">", a>b, "<", a<b)
  elif ch == 3:
    age = int(input("Age: "))
    salary = int(input("Salary: "))
    print(age > 24 and salary >35000 )
  elif ch == 4:
    x = int(input("Enter number: "))
    x += 5
    print("After +=5:", x)
  elif ch == 5:
    lst = [20, 30, 40]
    n =int(input("Enter number: "))
    print(n in list)
  elif ch == 6:
    a = [3, 5]
    b = a
    print(a is b)
  elif ch == 7:
    a, b = map(int, input("Enter two numbers: ").split())
    print("AND:", a & b, "OR:", a | b, "XOR:", a ^ b)
  elif ch == 8:
    break
  else:
    print("Invalid choice")
# Out:
# 1.Arithmatic 2.Comparison 3.Logical 4.Assignment
# 5.Membership 6.Identity 7.Bitwise 8. Exit
# Enter choice: 4
# Enter number: 67
# After +=5: 72
#
# 1.Arithmatic 2.Comparison 3.Logical 4.Assignment
# 5.Membership 6.Identity 7.Bitwise 8. Exit
