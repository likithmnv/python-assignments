# %%
x = ("Edukron")
x[0:6]
# Out:
# 'Edukro'

# %%
y = ("Edukron")
y[1:7]
# Out:
# 'dukron'

# %%
x = ("data")
x[0:4]
# Out:
# 'data'

# %%
y = ("data")
y [1:5]
# Out:
# 'ata'

# %%
x = ("science")
x[0:7]
# Out:
# 'science'

# %%
y = ("science")
y[1:8]
# Out:
# 'cience'

# %%
x = ("and")
x[1:4]
# Out:
# 'nd'

# %%
y = ("and")
y[2:5]
# Out:
# 'd'

# %%
x = ("data engineer")
x[1:12]
# Out:
# 'ata enginee'

# %%
y = ("data engineer")
y[6:12]
# Out:
# 'nginee'

# %%
x = ("engineering")
x[1:6]
# Out:
# 'ngine'

# %%
y = ("engineering")
y[6:8]
# Out:
# 'er'

# %%
x = ("batch")
x[1:6]
# Out:
# 'atch'

# %%
y = ("batch")
y[3:6]
# Out:
# 'ch'

# %%
x = ("2026")
x[1:5]
# Out:
# '026'

# %%
y = ("2026")
y[2:4]
# Out:
# '26'

# %%
x = ("science and data")
x[1:15]
# Out:
# 'cience and dat'

# %%
y = ("science and data")
y [12:15]
# Out:
# 'dat'

# %%
x = ("data science and engineering batch")
x[11:30]
# Out:
# 'e and engineering b'

# %%
y = ("data acience and engineering batch")
y[20:30]
# Out:
# 'ineering b'
